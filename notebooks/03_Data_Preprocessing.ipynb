# %%
import pandas as pd

df = pd.read_csv("../data/raw/medical_insurance.csv")

# %%
df = df.drop(columns=["person_id"])

# %%
df.shape
# Out:
# (100000, 53)

# %%
df.to_csv(
    "../data/processed/medical_insurance_processed.csv",
    index=False
)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'region', 'urban_rural', 'income', 'education',
#        'marital_status', 'employment_status', 'household_size', 'dependents',
#        'bmi', 'smoker', 'alcohol_freq', 'visits_last_year',
#        'hospitalizations_last_3yrs', 'days_hospitalized_last_3yrs',
#        'medication_count', 'systolic_bp', 'diastolic_bp', 'ldl', 'hba1c',
#        'plan_type', 'network_tier', 'deductible', 'copay', 'policy_term_years',
#        'policy_changes_last_2yrs', 'provider_quality', 'risk_score',
#        'annual_medical_cost', 'annual_premium', 'monthly_premium',
#        'claims_count', 'avg_claim_amount', 'total_claims_paid',
#        'chronic_count', 'hypertension', 'diabetes', 'asthma', 'copd',
#        'cardiovascular_disease', 'cancer_history', 'kidney_disease',
#        'liver_disease', 'arthritis', 'mental_health', 'proc_imaging_count',
#        'proc_surgery_count', 'proc_physio_count', 'proc_consult_count',
#        'proc_lab_count', 'is_high_risk', 'had_major_procedure'],
#       dtype='str')

# %%
X = df.drop(columns=["annual_medical_cost"])

y = df["annual_medical_cost"]

# %%
print("Features Shape:", X.shape)
print("Target Shape:", y.shape)
# Out:
# Features Shape: (100000, 52)
# Target Shape: (100000,)

# %%
X.head()
# Out:
#    age     sex   region urban_rural   income     education marital_status  \
# 0   52  Female    North    Suburban  22700.0     Doctorate        Married
# 1   79  Female    North       Urban  12800.0         No HS        Married
# 2   68    Male    North       Rural  40700.0            HS        Married
# 3   15    Male    North    Suburban  15600.0  Some College        Married
# 4   53    Male  Central    Suburban  89600.0     Doctorate        Married
#
#   employment_status  household_size  dependents  ...  liver_disease arthritis  \
# 0           Retired               3           1  ...              0         1
# 1          Employed               3           1  ...              0         1
# 2           Retired               5           3  ...              0         0
# 3     Self-employed               5           3  ...              0         0
# 4     Self-employed               2           0  ...              0         1
#
#   mental_health  proc_imaging_count  proc_surgery_count  proc_physio_count  \
# 0             0                   1                   0                  2
# 1             1                   0                   0                  1
# 2             1                   1                   0                  2
# 3             0                   1                   0                  0
# 4             0                   2                   0                  1
#
#    proc_consult_count  proc_lab_count  is_high_risk  had_major_procedure
# 0                   0               1             0                    0
# 1                   0               1             1                    0
# 2                   1               0             1                    0
# 3                   1               0             0                    0
# 4                   1               0             1                    0
#
# [5 rows x 52 columns]

# %%
y.head()
# Out:
# 0    6938.06
# 1    1632.61
# 2    7661.01
# 3    5130.27
# 4    1700.73
# Name: annual_medical_cost, dtype: float64
